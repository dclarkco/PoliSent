# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
df = pd.read_csv('test.csv')

# %%
chart = alt.Chart(df).mark_point().encode(
    x='gopShare',
    y='Chick-Fil-A _trends'
)
chart
# Out:
# alt.Chart(...)

# %%
test1 = [1,2,3,4,5]
test2 = [1,2,3,4,5]
ndf = pd.DataFrame(columns=['t1','t2'])
ndf['t1'] = test1
ndf['t2'] = test2

# %%
ndf
# Out:
#    t1  t2
# 0   1   1
# 1   2   2
# 2   3   3
# 3   4   4
# 4   5   5

# %%
chart = alt.Chart(ndf).mark_point().encode(
    x='t1',
    y='t2'
)
chart.save('test.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\altair\utils\mimebundle.py in spec_to_mimebundle(spec, format, mode, vega_version, vegaembed_version, vegalite_version, **kwargs)
#      53         try:
# ---> 54             import altair_saver
#      55         except ImportError:
#
# ModuleNotFoundError: No module named 'altair_saver'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25360/3302127705.py in <module>
#       3     y='t2'
#       4 )
# ----> 5 chart.save('test.png')
#
# ~\Anaconda3\lib\site-packages\altair\vegalite\v4\api.py in save(self, fp, format, override_data_transformer, scale_factor, vegalite_version, vega_version, vegaembed_version, **kwargs)
#     474         if override_data_transformer:
# ...
