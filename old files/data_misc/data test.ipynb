# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('houes.csv',encoding = "ISO-8859-1")

# %%
te = df[df['year']==2018]

# %%
mn = te[te['state_po']=='MN']

# %%
mn
# Out:
#        year      state state_po  state_fips  state_cen  state_ic    office  \
# 28778  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28779  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28780  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28781  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28782  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28783  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28784  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28785  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28786  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28787  2018  MINNESOTA       MN          27         41        33  US HOUSE
# 28788  2018  MINNESOTA       MN          27         41        33  US HOUSE
# ...

# %%
nd = te[te['state_po']=='ND']

# %%
nd
# Out:
#        year         state state_po  state_fips  state_cen  state_ic    office  \
# 29148  2018  NORTH DAKOTA       ND          38         44        36  US HOUSE
# 29149  2018  NORTH DAKOTA       ND          38         44        36  US HOUSE
# 29150  2018  NORTH DAKOTA       ND          38         44        36  US HOUSE
# 29151  2018  NORTH DAKOTA       ND          38         44        36  US HOUSE
#
#        district stage runoff  special        candidate           party  \
# 29148         0   gen    NaN    False  KELLY ARMSTRONG      REPUBLICAN
# 29149         0   gen    NaN    False    MAC SCHNEIDER  DEMOCRATIC-NPL
# 29150         0   gen    NaN    False   CHARLES TUTTLE     INDEPENDENT
# 29151         0   gen    NaN    False              NaN             NaN
#
#        writein   mode  candidatevotes  totalvotes  unofficial   version  \
# 29148    False  TOTAL          193568      321532       False  20210604
# 29149    False  TOTAL          114377      321532       False  20210604
# ...

# %%
ts = df[df['year']==2016]

# %%
vt = ts[ts['state_po']=='VT']

# %%
vt
# Out:
#        year    state state_po  state_fips  state_cen  state_ic    office  \
# 28146  2016  VERMONT       VT          50         13         6  US HOUSE
# 28147  2016  VERMONT       VT          50         13         6  US HOUSE
# 28148  2016  VERMONT       VT          50         13         6  US HOUSE
# 28149  2016  VERMONT       VT          50         13         6  US HOUSE
# 28150  2016  VERMONT       VT          50         13         6  US HOUSE
#
#        district stage runoff  special      candidate          party  writein  \
# 28146         0   gen    NaN    False            NaN            NaN     True
# 28147         0   gen    NaN    False    PETER WELCH       DEMOCRAT    False
# 28148         0   gen    NaN    False      VOID VOTE            NaN    False
# 28149         0   gen    NaN    False  ERICA CLAWSON  LIBERTY UNION    False
# 28150         0   gen    NaN    False     BLANK VOTE            NaN    False
#
# ...

# %%
mr = 10**-8
rate = (mr*mr)
for i in range(1,1000000000):
    if (i*rate) >=1:
        print(i)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_900/2266139788.py in <module>
#       2 rate = (mr*mr)
#       3 for i in range(1,1000000000):
# ----> 4     if (i*rate) >=1:
#       5         print(i)
#       6         break
#
# KeyboardInterrupt:

# %%
mr
